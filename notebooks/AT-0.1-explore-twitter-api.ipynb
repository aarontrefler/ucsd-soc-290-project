# %%
import json

import tweepy
from tweepy import OAuthHandler

# %%
consumer_key = 'W1vEEpGJawjrqeW70yBUkfrWt'
consumer_secret = 'PSNivPYzJCjvEeQ5WW0zAhAIbAoEdzQBjTUG39up4yhnW9HABi'
access_token = '289683843-a9GiDa84Ak7FqD8c8Cu1qYzA5oEVqQ1FSKjkSudP'
access_secret = 'O3KhEusOxqTJGI6zvh8eqlDbyGyUT4tKThymbr57YFHWx'
 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %%
json?

# %%
def process_or_store(tweet):
    print(json.dumps(tweet, sort_keys=True, indent=4))

# %%
# Read timeline posts
for status in tweepy.Cursor(api.home_timeline).items(1):
    # Process a single status
    process_or_store(status._json)
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Tue Oct 24 23:43:23 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "keeverbook.org",
#                 "expanded_url": "http://keeverbook.org",
#                 "indices": [
#                     101,
#                     124
#                 ],
#                 "url": "https://t.co/bJQX1nVYqj"
#             }
#         ],
#         "user_mentions": [
#             {
#                 "id": 901193380260196352,
#                 "id_str": "901193380260196352",
#                 "indices": [
#                     3,
#                     18
#                 ],
#                 "name": "KeeverBook.org",
#                 "screen_name": "keeverbook_org"
#             },
#             {
#                 "id": 1344951,
#                 "id_str": "1344951",
#                 "indices": [
#                     30,
#                     36
#                 ],
#                 "name": "WIRED",
#                 "screen_name": "WIRED"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 922971813902131200,
#     "id_str": "922971813902131200",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 2,
#     "retweeted": false,
#     "retweeted_status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Tue Oct 17 20:52:28 +0000 2017",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "keeverbook.org",
#                     "expanded_url": "http://keeverbook.org",
#                     "indices": [
#                         81,
#                         104
#                     ],
#                     "url": "https://t.co/bJQX1nVYqj"
#                 },
#                 {
#                     "display_url": "wired.com/story/these-ab\u2026",
#                     "expanded_url": "https://www.wired.com/story/these-abstract-prints-turn-physics-into-art/",
#                     "indices": [
#                         105,
#                         128
#                     ],
#                     "url": "https://t.co/ckGgPhMBCA"
#                 }
#             ],
#             "user_mentions": [
#                 {
#                     "id": 1344951,
#                     "id_str": "1344951",
#                     "indices": [
#                         10,
#                         16
#                     ],
#                     "name": "WIRED",
#                     "screen_name": "WIRED"
#                 }
#             ]
#         },
#         "favorite_count": 1,
#         "favorited": false,
#         "geo": null,
#         "id": 920392087530590208,
#         "id_str": "920392087530590208",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "possibly_sensitive": false,
#         "possibly_sensitive_appealable": false,
#         "retweet_count": 2,
#         "retweeted": false,
#         "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#         "text": "Thanks to @WIRED for the gorgeous video on Kim Keever and his new book project - https://t.co/bJQX1nVYqj https://t.co/ckGgPhMBCA",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Fri Aug 25 21:23:39 +0000 2017",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "Give Art Books to Students.",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "keeverbook.org",
#                             "expanded_url": "http://keeverbook.org",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/TQuztHIo1L"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 3,
#             "follow_request_sent": false,
#             "followers_count": 2,
#             "following": false,
#             "friends_count": 9,
#             "geo_enabled": false,
#             "has_extended_profile": false,
#             "id": 901193380260196352,
#             "id_str": "901193380260196352",
#             "is_translation_enabled": false,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 0,
#             "location": "New York, NY",
#             "name": "KeeverBook.org",
#             "notifications": false,
#             "profile_background_color": "000000",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/901193380260196352/1508248133",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/918173295480135680/u1t4VnY-_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/918173295480135680/u1t4VnY-_normal.jpg",
#             "profile_link_color": "981CEB",
#             "profile_sidebar_border_color": "000000",
#             "profile_sidebar_fill_color": "000000",
#             "profile_text_color": "000000",
#             "profile_use_background_image": false,
#             "protected": false,
#             "screen_name": "keeverbook_org",
#             "statuses_count": 5,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/TQuztHIo1L",
#             "utc_offset": null,
#             "verified": false
#         }
#     },
#     "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#     "text": "RT @keeverbook_org: Thanks to @WIRED for the gorgeous video on Kim Keever and his new book project - https://t.co/bJQX1nVYqj https://t.co/c\u2026",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Sat Mar 17 09:57:25 +0000 2007",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "WIRED is where tomorrow is realized.",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "WIRED.com",
#                         "expanded_url": "http://WIRED.com",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/KT14PZrouQ"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 1740,
#         "follow_request_sent": false,
#         "followers_count": 9722900,
#         "following": true,
#         "friends_count": 308,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 1344951,
#         "id_str": "1344951",
#         "is_translation_enabled": true,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 90012,
#         "location": "San Francisco/New York",
#         "name": "WIRED",
#         "notifications": false,
#         "profile_background_color": "000000",
#         "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/734548027/5e5ee18945d22a9e2d9971208971bfdd.jpeg",
#         "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/734548027/5e5ee18945d22a9e2d9971208971bfdd.jpeg",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/1344951/1508778770",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/615598832726970372/jsK-gBSt_normal.png",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/615598832726970372/jsK-gBSt_normal.png",
#         "profile_link_color": "99DCF0",
#         "profile_sidebar_border_color": "FFFFFF",
#         "profile_sidebar_fill_color": "EEEEEE",
#         "profile_text_color": "000000",
#         "profile_use_background_image": false,
#         "protected": false,
#         "screen_name": "WIRED",
#         "statuses_count": 84046,
#         "time_zone": "Pacific Time (US & Canada)",
#         "translator_type": "none",
#         "url": "https://t.co/KT14PZrouQ",
#         "utc_offset": -25200,
#         "verified": true
#     }
# }

# %%
# Get followers
for friend in tweepy.Cursor(api.friends).items(1):
    process_or_store(friend._json)
# Out:
# {
#     "blocked_by": false,
#     "blocking": false,
#     "contributors_enabled": false,
#     "created_at": "Tue Apr 05 14:32:30 +0000 2016",
#     "default_profile": false,
#     "default_profile_image": false,
#     "description": "Wannabe psych/anthrop/endocrin-ologist; @PSU_sexuality and @PSU_Anthro student",
#     "entities": {
#         "description": {
#             "urls": []
#         }
#     },
#     "favourites_count": 137,
#     "follow_request_sent": false,
#     "followers_count": 78,
#     "following": true,
#     "friends_count": 274,
#     "geo_enabled": false,
#     "has_extended_profile": false,
#     "id": 717359259864997888,
#     "id_str": "717359259864997888",
#     "is_translation_enabled": false,
#     "is_translator": false,
#     "lang": "en",
#     "listed_count": 3,
#     "live_following": false,
#     "location": "",
#     "muting": false,
#     "name": "Talia Shirazi",
#     "notifications": false,
#     "profile_background_color": "000000",
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#     "profile_background_tile": false,
#     "profile_image_url": "http://pbs.twimg.com/profile_images/769143342709997568/EDqUywZn_normal.jpg",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/769143342709997568/EDqUywZn_normal.jpg",
#     "profile_link_color": "FF691F",
#     "profile_sidebar_border_color": "000000",
#     "profile_sidebar_fill_color": "000000",
#     "profile_text_color": "000000",
#     "profile_use_background_image": false,
#     "protected": false,
#     "screen_name": "talia_shirazi",
#     "status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Mon Oct 23 13:28:23 +0000 2017",
#         "entities": {
#             "hashtags": [
#                 {
#                     "indices": [
#                         35,
#                         49
#                     ],
#                     "text": "Overdiagnosis"
#                 },
#                 {
#                     "indices": [
#                         90,
#                         103
#                     ],
#                     "text": "mentalhealth"
#                 },
#                 {
#                     "indices": [
#                         104,
#                         115
#                     ],
#                     "text": "psychiatry"
#                 },
#                 {
#                     "indices": [
#                         116,
#                         123
#                     ],
#                     "text": "school"
#                 },
#                 {
#                     "indices": [
#                         124,
#                         135
#                     ],
#                     "text": "psychology"
#                 }
#             ],
#             "symbols": [],
#             "urls": [],
#             "user_mentions": [
#                 {
#                     "id": 458674855,
#                     "id_str": "458674855",
#                     "indices": [
#                         3,
#                         18
#                     ],
#                     "name": "Mad In America",
#                     "screen_name": "Mad_In_America"
#                 }
#             ]
#         },
#         "favorite_count": 0,
#         "favorited": false,
#         "geo": null,
#         "id": 922454659012407296,
#         "id_str": "922454659012407296",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "retweet_count": 10,
#         "retweeted": false,
#         "retweeted_status": {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Wed Oct 18 13:01:09 +0000 2017",
#             "entities": {
#                 "hashtags": [
#                     {
#                         "indices": [
#                             15,
#                             29
#                         ],
#                         "text": "Overdiagnosis"
#                     },
#                     {
#                         "indices": [
#                             70,
#                             83
#                         ],
#                         "text": "mentalhealth"
#                     },
#                     {
#                         "indices": [
#                             84,
#                             95
#                         ],
#                         "text": "psychiatry"
#                     },
#                     {
#                         "indices": [
#                             96,
#                             103
#                         ],
#                         "text": "school"
#                     },
#                     {
#                         "indices": [
#                             104,
#                             115
#                         ],
#                         "text": "psychology"
#                     }
#                 ],
#                 "symbols": [],
#                 "urls": [
#                     {
#                         "display_url": "madinamerica.com/2017/10/study-\u2026",
#                         "expanded_url": "https://www.madinamerica.com/2017/10/study-examines-overdiagnosis-mental-health-disorders-childhood/",
#                         "indices": [
#                             116,
#                             139
#                         ],
#                         "url": "https://t.co/5xLkIBF5uF"
#                     }
#                 ],
#                 "user_mentions": []
#             },
#             "favorite_count": 12,
#             "favorited": false,
#             "geo": null,
#             "id": 920635865633869824,
#             "id_str": "920635865633869824",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "en",
#             "place": null,
#             "possibly_sensitive": false,
#             "retweet_count": 10,
#             "retweeted": false,
#             "source": "<a href=\"http://www.hootsuite.com\" rel=\"nofollow\">Hootsuite</a>",
#             "text": "Study Examines #Overdiagnosis of Mental Health Disorders in Childhood\n#mentalhealth #psychiatry #school #psychology\nhttps://t.co/5xLkIBF5uF",
#             "truncated": false
#         },
#         "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#         "text": "RT @Mad_In_America: Study Examines #Overdiagnosis of Mental Health Disorders in Childhood\n#mentalhealth #psychiatry #school #psychology\nhtt\u2026",
#         "truncated": false
#     },
#     "statuses_count": 96,
#     "time_zone": null,
#     "translator_type": "none",
#     "url": null,
#     "utc_offset": null,
#     "verified": false
# }

# %%
# Get my tweets
for tweet in tweepy.Cursor(api.user_timeline).items():
    process_or_store(tweet._json)
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sun Jan 08 16:46:10 +0000 2012",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 347073895,
#                 "id_str": "347073895",
#                 "indices": [
#                     29,
#                     45
#                 ],
#                 "name": "Kunu",
#                 "screen_name": "Luis_F_Gonzalez"
#             }
#         ]
#     },
#     "favorite_count": 1,
#     "favorited": false,
#     "geo": null,
#     "id": 156054095956946945,
#     "id_str": "156054095956946945",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 1,
#     "retweeted": false,
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "text": "Joining the bandwagon, maybe @Luis_F_Gonzalez",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Fri Apr 29 01:52:14 +0000 2011",
#         "default_profile": true,
#         "default_profile_image": true,
#         "description": "",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 1,
#         "follow_request_sent": false,
#         "followers_count": 3,
#         "following": false,
#         "friends_count": 13,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 289683843,
#         "id_str": "289683843",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 0,
#         "location": "",
#         "name": "Aaron Trefler",
#         "notifications": false,
#         "profile_background_color": "C0DEED",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#         "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "aarontrefler",
#         "statuses_count": 1,
#         "time_zone": "Pacific Time (US & Canada)",
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": -25200,
#         "verified": false
#     }
# }
