# %% [markdown]
# # Clean Feature Visualization

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %matplotlib inline

# %%
sns.set(context='notebook')
sns.set_palette("Set1")
sns.set_style("white")

# %%
df = pd.read_csv("../data/clean/features_clean.csv")
df = df.drop('Unnamed: 0', axis=1)
df_X = df.drop(['Trump_tweet_id', 'user_id'], axis=1)
df_X.drop(['age', 'gen_prob_Other'], axis=1, inplace=True)

# %%
n = df.shape[0]
print("Number of examples: {}".format(n))
# Out:
# Number of examples: 20854

# %%
df_X.hist(figsize=(20,15), bins=25)
plt.show()

# %%
corr = df_X.corr()
sns.heatmap(df_X.corr())
plt.show()

# %%
# PCA on user network features
from sklearn.decomposition import PCA
X = df_X[['user_favourites_count', 'user_friends_count',
             'user_statuses_count', 'user_followers_count']]

# %%
pca = PCA()
pca.fit(X)
pca.explained_variance_ratio_
# Out:
# array([ 0.77576063,  0.13904827,  0.05247691,  0.0327142 ])

# %%
pca = PCA(n_components=1)
pca.fit_transform(X)
# Out:
# array([[ 0.25004822],
#        [ 0.60690561],
#        [-0.02950427],
#        ...,
#        [ 0.51036265],
#        [ 3.72415273],
#        [ 2.20007433]])
